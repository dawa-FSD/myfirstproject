# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def introduce(self):
        print(f"My name is {self.name} and I am {self.age} years old")


student1 = Student("Dawa", 22)

student1.introduce()


# Encapsulation example

class Person:
    def __init__(self, name):
        self.name = name
        self.__salary = 5000

    def show_salary(self):
        return self.__salary


person1 = Person("Abebe")

print(person1.name)
print(person1.show_salary())
# Out:
# My name is Dawa and I am 22 years old
# Abebe
# 5000

# %%
class Account:
    def __init__(self, owner, balance):
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

    def display(self):
        print("Owner:", self.owner)
        print("Balance:", self.balance)


acc1 = Account("Almaz", 1500)

acc1.display()

acc1.deposit(500)

acc1.display()

almaz = Account("Almaz Bekele", 1500) 
dawit = Account("Dawit Tesfaye", 800) 
almaz.balance
# Out:
# Owner: Almaz
# Balance: 1500
# Owner: Almaz
# Balance: 2000
# 1500

# %%
class Account:
  def __init__(self, owner, balance):
      self.owner = owner 
      self.balance = balance
almaz = Account("Almaz", 1500) 
print(almaz.owner)
# Out:
# Almaz

# %%
class Account:
    def __init__(self, owner, balance):
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):  
        self.balance += amount

    def statement(self):
        print(f"{self.owner}: {self.balance} ETB")


almaz = Account("Almaz", 1500)

almaz.deposit(500)    
almaz.statement()
# Out:
# Almaz: 2000 ETB

# %%
class Account:
    def __init__(self, balance):
        self.balance = balance   

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds")
            return

        self.balance -= amount
        print(f"Withdrawal successful. New balance: {self.balance}")

# %%
class Account:
    def __init__(self, balance):
        self.__balance = balance

    @property
    def balance(self): 
        return self.__balance

    @balance.setter
    def balance(self, value): 
        if value < 0:
            raise ValueError("No negative balance")
        self.__balance = value


a = Account(1500)

print(a.balance)     

a.balance = 2000     
print(a.balance)   

a.balance -= 5
# Out:
# 1500
# 2000
