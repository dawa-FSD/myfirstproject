# %%
#Exercis of Day 02 num 1

tempreture=float(input("Enter temperature in °C:"))
if tempreture <15:
    print("cold")
elif tempreture >=28:
    print("Warm")
else:
    print("hot")
# Out:
# Enter temperature in °C: 18.733
# hot

# %%
#Exercis of Day 02 num 2

for i in range(1,10):
 print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#Exercis of Day 02 num 3

for i in range(2,20,2):
    print(i)
# Out:
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# 18

# %%
#Exercis of Day 02 num 4

def apply_discount(price, percent=10):
    discount = price * percent / 100
    return price - discount

print(apply_discount(100))
print(apply_discount(100, 20))
# Out:
# 90.0
# 80.0

# %%
#Exercis of Day 02 num 5

i = 5

while i >= 1:
    print(i)
    i -= 1

print("Liftoff!")
# Out:
# 5
# 4
# 3
# 2
# 1
# Liftoff!
